# %% [markdown]
# # Terminal DETM with RAM

# %%
# -*- coding: utf-8 -*-
from google.colab import drive
drive.mount('/content/drive', force_remount= True)
# Out:
# Mounted at /content/drive

# %%
import time
import os
# %matplotlib inline

# %pwd
# %cd "/content/drive/My Drive/Masterarbeit/topics_over_time"
# %ls
# Out:
# /content/drive/My Drive/Masterarbeit/topics_over_time
#  _archive/      __pycache__/      'TOT Preprocessing Technology-Data.ipynb'
#  GPL.md         README.md          tot.py
#  main_pnas.py   results/          'TOT Terminal_RAM.ipynb'
#  pnas_all/      src/               visualize_pnas.py
#  pnas_all.tar   technology-data/

# %%
# %run main_pnas.py
# Out:
# Done with iteration 0 and document 0
# Done with iteration 0 and document 1000
# Done with iteration 0 and document 2000
# Done with iteration 0 and document 3000
# Done with iteration 0 and document 4000
# Done with iteration 0 and document 5000
# Done with iteration 0 and document 6000
# Done with iteration 0 and document 7000
# Done with iteration 0 and document 8000
# Done with iteration 0 and document 9000
# Done with iteration 0 and document 10000
# Done with iteration 0 and document 11000
# Done with iteration 0 and document 12000
# Done with iteration 0 and document 13000
# Done with iteration 0 and document 14000
# Done with iteration 0 and document 15000
# Done with iteration 0 and document 16000
# Done with iteration 0 and document 17000
# Done with iteration 0 and document 18000
# Done with iteration 0 and document 19000
# Done with iteration 0 and document 20000
# Done with iteration 0 and document 21000
# Done with iteration 0 and document 22000
# ...
